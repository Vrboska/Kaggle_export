# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import random
import mofr
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier, plot_tree
from lightgbm import LGBMRanker, plot_tree
import math
import pickle


import xgboost as xgb

# %%
file_name1 = "otto_xgb_model_12_lb_582.pkl"
file_name2 = "otto_xgb_model_12_lb_582.pkl"
file_name3 = "otto_xgb_model_12_lb_582.pkl"


#load
xgb_model_clicks= pickle.load(open(file_name1, "rb"))
xgb_model_carts= pickle.load(open(file_name2, "rb"))
xgb_model_orders= pickle.load(open(file_name3, "rb"))

# %%
def process_chunk(chunk):   
    chunk['null_flag']=(chunk['avg_order_hours_from_click_avg']<99999).apply(int)
    chunk['in_session_carted_not_ordered']=((chunk['in_session_carted']>0)&(chunk['in_session_ordered']==0)).apply(int)

    chunk['XGB_SCORE']=xgb_model.predict_proba(chunk[xgb_model.feature_names_in_])[:, 1]

    a=chunk[['session_id', 'aid', 'XGB_SCORE']].groupby('session_id').apply(lambda x : x.sort_values(by = ['XGB_SCORE'], ascending = [False]).head(20).reset_index(drop = True)).reset_index(drop = True)
    a['session_id']=a['session_id'].apply(str)
    a['aid']=a['aid'].apply(lambda x: str(int(x)))
    
    b=pd.DataFrame(a.groupby('session_id')['aid'].apply(list).apply(' '.join)).reset_index(drop=False).rename(columns={'aid':'labels'})
    return b

# %%
n=0
submission=pd.DataFrame()

for x in range(1):
    for y in range(30):
        for z in range (30):
            print(x,y,z)
            print(f'File number {n} being processed')
            #print(f'{n}: {round(n/0.45,2)} % files done')
            try: 
                df=pd.read_parquet(r'c:\Users\AZUBA\Downloads\data_'+str(x)+'_'+str(y)+'_'+str(z)+'.snappy.parquet')
                print('File read.')
                df.columns=[x.lower() for x in df.columns]
                submission=pd.concat([submission,process_chunk(df)])
                n+=1
            except:
                print(f'File test_{str(x)}_{str(y)}_{str(z)}.snappy.parquet not processed')
# Out:
# 0 0 0
# File number 0 being processed
# File read.
# 0 0 1
# File number 1 being processed
# File read.
# 0 0 2
# File number 2 being processed
# File read.
# 0 0 3
# File number 3 being processed
# File read.
# 0 0 4
# File number 4 being processed
# File read.
# 0 0 5
# File number 5 being processed
# File read.
# 0 0 6
# File number 6 being processed
# File read.
# 0 0 7
# File number 7 being processed
# File read.
# 0 0 8
# File number 8 being processed
# File read.
# 0 0 9
# File number 9 being processed
# File read.
# 0 0 10
# File number 10 being processed
# File read.
# 0 0 11
# File number 11 being processed
# File read.
# 0 0 12
# File number 12 being processed
# File read.
# 0 0 13
# File number 13 being processed
# File read.
# 0 0 14
# File number 14 being processed
# File read.
# 0 0 15
# File number 15 being processed
# File read.
# 0 0 16
# File number 16 being processed
# File read.
# 0 0 17
# File number 17 being processed
# File read.
# 0 0 18
# File number 18 being processed
# File read.
# 0 0 19
# File number 19 being processed
# File read.
# 0 0 20
# File number 20 being processed
# File read.
# 0 0 21
# File number 21 being processed
# File read.
# 0 0 22
# File number 22 being processed
# File test_0_0_22.snappy.parquet not processed
# 0 0 23
# File number 22 being processed
# File test_0_0_23.snappy.parquet not processed
# 0 0 24
# File number 22 being processed
# File test_0_0_24.snappy.parquet not processed
# 0 0 25
# File number 22 being processed
# File test_0_0_25.snappy.parquet not processed
# 0 0 26
# File number 22 being processed
# File test_0_0_26.snappy.parquet not processed
# 0 0 27
# File number 22 being processed
# File test_0_0_27.snappy.parquet not processed
# 0 0 28
# File number 22 being processed
# File test_0_0_28.snappy.parquet not processed
# 0 0 29
# File number 22 being processed
# File test_0_0_29.snappy.parquet not processed
# 0 1 0
# File number 22 being processed
# File read.
# 0 1 1
# File number 23 being processed
# File read.
# 0 1 2
# File number 24 being processed
# File read.
# 0 1 3
# File number 25 being processed
# File read.
# 0 1 4
# File number 26 being processed
# File read.
# 0 1 5
# File number 27 being processed
# File read.
# 0 1 6
# File number 28 being processed
# File read.
# 0 1 7
# File number 29 being processed
# File read.
# 0 1 8
# File number 30 being processed
# File read.
# 0 1 9
# File number 31 being processed
# File read.
# 0 1 10
# File number 32 being processed
# File read.
# 0 1 11
# File number 33 being processed
# File read.
# 0 1 12
# File number 34 being processed
# File read.
# 0 1 13
# File number 35 being processed
# File read.
# 0 1 14
# File number 36 being processed
# File read.
# 0 1 15
# File number 37 being processed
# File read.
# 0 1 16
# File number 38 being processed
# File read.
# 0 1 17
# File number 39 being processed
# File read.
# 0 1 18
# File number 40 being processed
# File read.
# 0 1 19
# File number 41 being processed
# File read.
# 0 1 20
# File number 42 being processed
# File read.
# 0 1 21
# File number 43 being processed
# File read.
# 0 1 22
# File number 44 being processed
# File test_0_1_22.snappy.parquet not processed
# 0 1 23
# File number 44 being processed
# File test_0_1_23.snappy.parquet not processed
# 0 1 24
# File number 44 being processed
# File test_0_1_24.snappy.parquet not processed
# 0 1 25
# File number 44 being processed
# File test_0_1_25.snappy.parquet not processed
# 0 1 26
# File number 44 being processed
# File test_0_1_26.snappy.parquet not processed
# 0 1 27
# File number 44 being processed
# File test_0_1_27.snappy.parquet not processed
# 0 1 28
# File number 44 being processed
# File test_0_1_28.snappy.parquet not processed
# 0 1 29
# File number 44 being processed
# File test_0_1_29.snappy.parquet not processed
# 0 2 0
# File number 44 being processed
# File read.
# 0 2 1
# File number 45 being processed
# File read.
# 0 2 2
# File number 46 being processed
# File read.
# 0 2 3
# File number 47 being processed
# File read.
# 0 2 4
# File number 48 being processed
# File read.
# 0 2 5
# File number 49 being processed
# File read.
# 0 2 6
# File number 50 being processed
# File read.
# 0 2 7
# File number 51 being processed
# File read.
# 0 2 8
# File number 52 being processed
# File read.
# 0 2 9
# File number 53 being processed
# File read.
# 0 2 10
# File number 54 being processed
# File read.
# 0 2 11
# File number 55 being processed
# File read.
# 0 2 12
# File number 56 being processed
# File read.
# 0 2 13
# File number 57 being processed
# File read.
# 0 2 14
# File number 58 being processed
# File read.
# 0 2 15
# File number 59 being processed
# File read.
# 0 2 16
# File number 60 being processed
# File read.
# 0 2 17
# File number 61 being processed
# File read.
# 0 2 18
# File number 62 being processed
# File read.
# 0 2 19
# File number 63 being processed
# File read.
# 0 2 20
# File number 64 being processed
# File read.
# 0 2 21
# File number 65 being processed
# File read.
# 0 2 22
# File number 66 being processed
# File test_0_2_22.snappy.parquet not processed
# 0 2 23
# File number 66 being processed
# File test_0_2_23.snappy.parquet not processed
# 0 2 24
# File number 66 being processed
# File test_0_2_24.snappy.parquet not processed
# 0 2 25
# File number 66 being processed
# File test_0_2_25.snappy.parquet not processed
# 0 2 26
# File number 66 being processed
# File test_0_2_26.snappy.parquet not processed
# 0 2 27
# File number 66 being processed
# File test_0_2_27.snappy.parquet not processed
# 0 2 28
# File number 66 being processed
# File test_0_2_28.snappy.parquet not processed
# 0 2 29
# File number 66 being processed
# File test_0_2_29.snappy.parquet not processed
# 0 3 0
# File number 66 being processed
# File read.
# 0 3 1
# File number 67 being processed
# File read.
# 0 3 2
# File number 68 being processed
# File read.
# 0 3 3
# File number 69 being processed
# File read.
# 0 3 4
# File number 70 being processed
# File read.
# 0 3 5
# File number 71 being processed
# File read.
# 0 3 6
# File number 72 being processed
# File read.
# 0 3 7
# File number 73 being processed
# File read.
# 0 3 8
# File number 74 being processed
# File read.
# 0 3 9
# File number 75 being processed
# File read.
# 0 3 10
# File number 76 being processed
# File read.
# 0 3 11
# File number 77 being processed
# File read.
# 0 3 12
# File number 78 being processed
# File read.
# 0 3 13
# File number 79 being processed
# File read.
# 0 3 14
# File number 80 being processed
# File read.
# 0 3 15
# File number 81 being processed
# File read.
# 0 3 16
# File number 82 being processed
# File read.
# 0 3 17
# File number 83 being processed
# File read.
# 0 3 18
# File number 84 being processed
# File read.
# 0 3 19
# File number 85 being processed
# File read.
# 0 3 20
# File number 86 being processed
# File read.
# 0 3 21
# File number 87 being processed
# File test_0_3_21.snappy.parquet not processed
# 0 3 22
# File number 87 being processed
# File test_0_3_22.snappy.parquet not processed
# 0 3 23
# File number 87 being processed
# File test_0_3_23.snappy.parquet not processed
# 0 3 24
# File number 87 being processed
# File test_0_3_24.snappy.parquet not processed
# 0 3 25
# File number 87 being processed
# File test_0_3_25.snappy.parquet not processed
# 0 3 26
# File number 87 being processed
# File test_0_3_26.snappy.parquet not processed
# 0 3 27
# File number 87 being processed
# File test_0_3_27.snappy.parquet not processed
# 0 3 28
# File number 87 being processed
# File test_0_3_28.snappy.parquet not processed
# 0 3 29
# File number 87 being processed
# File test_0_3_29.snappy.parquet not processed
# 0 4 0
# File number 87 being processed
# File read.
# 0 4 1
# File number 88 being processed
# File read.
# 0 4 2
# File number 89 being processed
# File read.
# 0 4 3
# File number 90 being processed
# File read.
# 0 4 4
# File number 91 being processed
# File read.
# 0 4 5
# File number 92 being processed
# File read.
# 0 4 6
# File number 93 being processed
# File read.
# 0 4 7
# File number 94 being processed
# File read.
# 0 4 8
# File number 95 being processed
# File read.
# 0 4 9
# File number 96 being processed
# File read.
# 0 4 10
# File number 97 being processed
# File read.
# 0 4 11
# File number 98 being processed
# File read.
# 0 4 12
# File number 99 being processed
# File read.
# 0 4 13
# File number 100 being processed
# File read.
# 0 4 14
# File number 101 being processed
# File read.
# 0 4 15
# File number 102 being processed
# File read.
# 0 4 16
# File number 103 being processed
# File read.
# 0 4 17
# File number 104 being processed
# File read.
# 0 4 18
# File number 105 being processed
# File read.
# 0 4 19
# File number 106 being processed
# File read.
# 0 4 20
# File number 107 being processed
# File read.
# 0 4 21
# File number 108 being processed
# File test_0_4_21.snappy.parquet not processed
# 0 4 22
# File number 108 being processed
# File test_0_4_22.snappy.parquet not processed
# 0 4 23
# File number 108 being processed
# File test_0_4_23.snappy.parquet not processed
# 0 4 24
# File number 108 being processed
# File test_0_4_24.snappy.parquet not processed
# 0 4 25
# File number 108 being processed
# File test_0_4_25.snappy.parquet not processed
# 0 4 26
# File number 108 being processed
# File test_0_4_26.snappy.parquet not processed
# 0 4 27
# File number 108 being processed
# File test_0_4_27.snappy.parquet not processed
# 0 4 28
# File number 108 being processed
# File test_0_4_28.snappy.parquet not processed
# 0 4 29
# File number 108 being processed
# File test_0_4_29.snappy.parquet not processed
# 0 5 0
# File number 108 being processed
# File read.
# 0 5 1
# File number 109 being processed
# File read.
# 0 5 2
# File number 110 being processed
# File read.
# 0 5 3
# File number 111 being processed
# File read.
# 0 5 4
# File number 112 being processed
# File read.
# 0 5 5
# File number 113 being processed
# File read.
# 0 5 6
# File number 114 being processed
# File read.
# 0 5 7
# File number 115 being processed
# File read.
# 0 5 8
# File number 116 being processed
# File read.
# 0 5 9
# File number 117 being processed
# File read.
# 0 5 10
# File number 118 being processed
# File read.
# 0 5 11
# File number 119 being processed
# File read.
# 0 5 12
# File number 120 being processed
# File read.
# 0 5 13
# File number 121 being processed
# File read.
# 0 5 14
# File number 122 being processed
# File read.
# 0 5 15
# File number 123 being processed
# File read.
# 0 5 16
# File number 124 being processed
# File read.
# 0 5 17
# File number 125 being processed
# File read.
# 0 5 18
# File number 126 being processed
# File read.
# 0 5 19
# File number 127 being processed
# File read.
# 0 5 20
# File number 128 being processed
# File read.
# 0 5 21
# File number 129 being processed
# File test_0_5_21.snappy.parquet not processed
# 0 5 22
# File number 129 being processed
# File test_0_5_22.snappy.parquet not processed
# 0 5 23
# File number 129 being processed
# File test_0_5_23.snappy.parquet not processed
# 0 5 24
# File number 129 being processed
# File test_0_5_24.snappy.parquet not processed
# 0 5 25
# File number 129 being processed
# File test_0_5_25.snappy.parquet not processed
# 0 5 26
# File number 129 being processed
# File test_0_5_26.snappy.parquet not processed
# 0 5 27
# File number 129 being processed
# File test_0_5_27.snappy.parquet not processed
# 0 5 28
# File number 129 being processed
# File test_0_5_28.snappy.parquet not processed
# 0 5 29
# File number 129 being processed
# File test_0_5_29.snappy.parquet not processed
# 0 6 0
# File number 129 being processed
# File read.
# 0 6 1
# File number 130 being processed
# File read.
# 0 6 2
# File number 131 being processed
# File read.
# 0 6 3
# File number 132 being processed
# File read.
# 0 6 4
# File number 133 being processed
# File read.
# 0 6 5
# File number 134 being processed
# File read.
# 0 6 6
# File number 135 being processed
# File read.
# 0 6 7
# File number 136 being processed
# File read.
# 0 6 8
# File number 137 being processed
# File read.
# 0 6 9
# File number 138 being processed
# File read.
# 0 6 10
# File number 139 being processed
# File read.
# 0 6 11
# File number 140 being processed
# File read.
# 0 6 12
# File number 141 being processed
# File read.
# 0 6 13
# File number 142 being processed
# File read.
# 0 6 14
# File number 143 being processed
# File read.
# 0 6 15
# File number 144 being processed
# File read.
# 0 6 16
# File number 145 being processed
# File read.
# 0 6 17
# File number 146 being processed
# File read.
# 0 6 18
# File number 147 being processed
# File read.
# 0 6 19
# File number 148 being processed
# File read.
# 0 6 20
# File number 149 being processed
# File read.
# 0 6 21
# File number 150 being processed
# File read.
# 0 6 22
# File number 151 being processed
# File test_0_6_22.snappy.parquet not processed
# 0 6 23
# File number 151 being processed
# File test_0_6_23.snappy.parquet not processed
# 0 6 24
# File number 151 being processed
# File test_0_6_24.snappy.parquet not processed
# 0 6 25
# File number 151 being processed
# File test_0_6_25.snappy.parquet not processed
# 0 6 26
# File number 151 being processed
# File test_0_6_26.snappy.parquet not processed
# 0 6 27
# File number 151 being processed
# File test_0_6_27.snappy.parquet not processed
# 0 6 28
# File number 151 being processed
# File test_0_6_28.snappy.parquet not processed
# 0 6 29
# File number 151 being processed
# File test_0_6_29.snappy.parquet not processed
# 0 7 0
# File number 151 being processed
# File read.
# 0 7 1
# File number 152 being processed
# File read.
# 0 7 2
# File number 153 being processed
# File read.
# 0 7 3
# File number 154 being processed
# File read.
# 0 7 4
# File number 155 being processed
# File read.
# 0 7 5
# File number 156 being processed
# File read.
# 0 7 6
# File number 157 being processed
# File read.
# 0 7 7
# File number 158 being processed
# File read.
# 0 7 8
# File number 159 being processed
# File read.
# 0 7 9
# File number 160 being processed
# File read.
# 0 7 10
# File number 161 being processed
# File read.
# 0 7 11
# File number 162 being processed
# File read.
# 0 7 12
# File number 163 being processed
# File read.
# 0 7 13
# File number 164 being processed
# File read.
# 0 7 14
# File number 165 being processed
# File read.
# 0 7 15
# File number 166 being processed
# File read.
# 0 7 16
# File number 167 being processed
# File read.
# 0 7 17
# File number 168 being processed
# File read.
# 0 7 18
# File number 169 being processed
# File read.
# 0 7 19
# File number 170 being processed
# File read.
# 0 7 20
# File number 171 being processed
# File read.
# 0 7 21
# File number 172 being processed
# File read.
# 0 7 22
# File number 173 being processed
# File test_0_7_22.snappy.parquet not processed
# 0 7 23
# File number 173 being processed
# File test_0_7_23.snappy.parquet not processed
# 0 7 24
# File number 173 being processed
# File test_0_7_24.snappy.parquet not processed
# 0 7 25
# File number 173 being processed
# File test_0_7_25.snappy.parquet not processed
# 0 7 26
# File number 173 being processed
# File test_0_7_26.snappy.parquet not processed
# 0 7 27
# File number 173 being processed
# File test_0_7_27.snappy.parquet not processed
# 0 7 28
# File number 173 being processed
# File test_0_7_28.snappy.parquet not processed
# 0 7 29
# File number 173 being processed
# File test_0_7_29.snappy.parquet not processed
# 0 8 0
# File number 173 being processed
# File test_0_8_0.snappy.parquet not processed
# 0 8 1
# File number 173 being processed
# File test_0_8_1.snappy.parquet not processed
# 0 8 2
# File number 173 being processed
# File test_0_8_2.snappy.parquet not processed
# 0 8 3
# File number 173 being processed
# File test_0_8_3.snappy.parquet not processed
# 0 8 4
# File number 173 being processed
# File test_0_8_4.snappy.parquet not processed
# 0 8 5
# File number 173 being processed
# File test_0_8_5.snappy.parquet not processed
# 0 8 6
# File number 173 being processed
# File test_0_8_6.snappy.parquet not processed
# 0 8 7
# File number 173 being processed
# File test_0_8_7.snappy.parquet not processed
# 0 8 8
# File number 173 being processed
# File test_0_8_8.snappy.parquet not processed
# 0 8 9
# File number 173 being processed
# File test_0_8_9.snappy.parquet not processed
# 0 8 10
# File number 173 being processed
# File test_0_8_10.snappy.parquet not processed
# 0 8 11
# File number 173 being processed
# File test_0_8_11.snappy.parquet not processed
# 0 8 12
# File number 173 being processed
# File test_0_8_12.snappy.parquet not processed
# 0 8 13
# File number 173 being processed
# File test_0_8_13.snappy.parquet not processed
# 0 8 14
# File number 173 being processed
# File test_0_8_14.snappy.parquet not processed
# 0 8 15
# File number 173 being processed
# File test_0_8_15.snappy.parquet not processed
# 0 8 16
# File number 173 being processed
# File test_0_8_16.snappy.parquet not processed
# 0 8 17
# File number 173 being processed
# File test_0_8_17.snappy.parquet not processed
# 0 8 18
# File number 173 being processed
# File test_0_8_18.snappy.parquet not processed
# 0 8 19
# File number 173 being processed
# File test_0_8_19.snappy.parquet not processed
# 0 8 20
# File number 173 being processed
# File test_0_8_20.snappy.parquet not processed
# 0 8 21
# File number 173 being processed
# File test_0_8_21.snappy.parquet not processed
# 0 8 22
# File number 173 being processed
# File test_0_8_22.snappy.parquet not processed
# 0 8 23
# File number 173 being processed
# File test_0_8_23.snappy.parquet not processed
# 0 8 24
# File number 173 being processed
# File test_0_8_24.snappy.parquet not processed
# 0 8 25
# File number 173 being processed
# File test_0_8_25.snappy.parquet not processed
# 0 8 26
# File number 173 being processed
# File test_0_8_26.snappy.parquet not processed
# 0 8 27
# File number 173 being processed
# File test_0_8_27.snappy.parquet not processed
# 0 8 28
# File number 173 being processed
# File test_0_8_28.snappy.parquet not processed
# 0 8 29
# File number 173 being processed
# File test_0_8_29.snappy.parquet not processed
# 0 9 0
# File number 173 being processed
# File test_0_9_0.snappy.parquet not processed
# 0 9 1
# File number 173 being processed
# File test_0_9_1.snappy.parquet not processed
# 0 9 2
# File number 173 being processed
# File test_0_9_2.snappy.parquet not processed
# 0 9 3
# File number 173 being processed
# File test_0_9_3.snappy.parquet not processed
# 0 9 4
# File number 173 being processed
# File test_0_9_4.snappy.parquet not processed
# 0 9 5
# File number 173 being processed
# File test_0_9_5.snappy.parquet not processed
# 0 9 6
# File number 173 being processed
# File test_0_9_6.snappy.parquet not processed
# 0 9 7
# File number 173 being processed
# File test_0_9_7.snappy.parquet not processed
# 0 9 8
# File number 173 being processed
# File test_0_9_8.snappy.parquet not processed
# 0 9 9
# File number 173 being processed
# File test_0_9_9.snappy.parquet not processed
# 0 9 10
# File number 173 being processed
# File test_0_9_10.snappy.parquet not processed
# 0 9 11
# File number 173 being processed
# File test_0_9_11.snappy.parquet not processed
# 0 9 12
# File number 173 being processed
# File test_0_9_12.snappy.parquet not processed
# 0 9 13
# File number 173 being processed
# File test_0_9_13.snappy.parquet not processed
# 0 9 14
# File number 173 being processed
# File test_0_9_14.snappy.parquet not processed
# 0 9 15
# File number 173 being processed
# File test_0_9_15.snappy.parquet not processed
# 0 9 16
# File number 173 being processed
# File test_0_9_16.snappy.parquet not processed
# 0 9 17
# File number 173 being processed
# File test_0_9_17.snappy.parquet not processed
# 0 9 18
# File number 173 being processed
# File test_0_9_18.snappy.parquet not processed
# 0 9 19
# File number 173 being processed
# File test_0_9_19.snappy.parquet not processed
# 0 9 20
# File number 173 being processed
# File test_0_9_20.snappy.parquet not processed
# 0 9 21
# File number 173 being processed
# File test_0_9_21.snappy.parquet not processed
# 0 9 22
# File number 173 being processed
# File test_0_9_22.snappy.parquet not processed
# 0 9 23
# File number 173 being processed
# File test_0_9_23.snappy.parquet not processed
# 0 9 24
# File number 173 being processed
# File test_0_9_24.snappy.parquet not processed
# 0 9 25
# File number 173 being processed
# File test_0_9_25.snappy.parquet not processed
# 0 9 26
# File number 173 being processed
# File test_0_9_26.snappy.parquet not processed
# 0 9 27
# File number 173 being processed
# File test_0_9_27.snappy.parquet not processed
# 0 9 28
# File number 173 being processed
# File test_0_9_28.snappy.parquet not processed
# 0 9 29
# File number 173 being processed
# File test_0_9_29.snappy.parquet not processed
# 0 10 0
# File number 173 being processed
# File test_0_10_0.snappy.parquet not processed
# 0 10 1
# File number 173 being processed
# File test_0_10_1.snappy.parquet not processed
# 0 10 2
# File number 173 being processed
# File test_0_10_2.snappy.parquet not processed
# 0 10 3
# File number 173 being processed
# File test_0_10_3.snappy.parquet not processed
# 0 10 4
# File number 173 being processed
# File test_0_10_4.snappy.parquet not processed
# 0 10 5
# File number 173 being processed
# File test_0_10_5.snappy.parquet not processed
# 0 10 6
# File number 173 being processed
# File test_0_10_6.snappy.parquet not processed
# 0 10 7
# File number 173 being processed
# File test_0_10_7.snappy.parquet not processed
# 0 10 8
# File number 173 being processed
# File test_0_10_8.snappy.parquet not processed
# 0 10 9
# File number 173 being processed
# File test_0_10_9.snappy.parquet not processed
# 0 10 10
# File number 173 being processed
# File test_0_10_10.snappy.parquet not processed
# 0 10 11
# File number 173 being processed
# File test_0_10_11.snappy.parquet not processed
# 0 10 12
# File number 173 being processed
# File test_0_10_12.snappy.parquet not processed
# 0 10 13
# File number 173 being processed
# File test_0_10_13.snappy.parquet not processed
# 0 10 14
# File number 173 being processed
# File test_0_10_14.snappy.parquet not processed
# 0 10 15
# File number 173 being processed
# File test_0_10_15.snappy.parquet not processed
# 0 10 16
# File number 173 being processed
# File test_0_10_16.snappy.parquet not processed
# 0 10 17
# File number 173 being processed
# File test_0_10_17.snappy.parquet not processed
# 0 10 18
# File number 173 being processed
# File test_0_10_18.snappy.parquet not processed
# 0 10 19
# File number 173 being processed
# File test_0_10_19.snappy.parquet not processed
# 0 10 20
# File number 173 being processed
# File test_0_10_20.snappy.parquet not processed
# 0 10 21
# File number 173 being processed
# File test_0_10_21.snappy.parquet not processed
# 0 10 22
# File number 173 being processed
# File test_0_10_22.snappy.parquet not processed
# 0 10 23
# File number 173 being processed
# File test_0_10_23.snappy.parquet not processed
# 0 10 24
# File number 173 being processed
# File test_0_10_24.snappy.parquet not processed
# 0 10 25
# File number 173 being processed
# File test_0_10_25.snappy.parquet not processed
# 0 10 26
# File number 173 being processed
# File test_0_10_26.snappy.parquet not processed
# 0 10 27
# File number 173 being processed
# File test_0_10_27.snappy.parquet not processed
# 0 10 28
# File number 173 being processed
# File test_0_10_28.snappy.parquet not processed
# 0 10 29
# File number 173 being processed
# File test_0_10_29.snappy.parquet not processed
# 0 11 0
# File number 173 being processed
# File test_0_11_0.snappy.parquet not processed
# 0 11 1
# File number 173 being processed
# File test_0_11_1.snappy.parquet not processed
# 0 11 2
# File number 173 being processed
# File test_0_11_2.snappy.parquet not processed
# 0 11 3
# File number 173 being processed
# File test_0_11_3.snappy.parquet not processed
# 0 11 4
# File number 173 being processed
# File test_0_11_4.snappy.parquet not processed
# 0 11 5
# File number 173 being processed
# File test_0_11_5.snappy.parquet not processed
# 0 11 6
# File number 173 being processed
# File test_0_11_6.snappy.parquet not processed
# 0 11 7
# File number 173 being processed
# File test_0_11_7.snappy.parquet not processed
# 0 11 8
# File number 173 being processed
# File test_0_11_8.snappy.parquet not processed
# 0 11 9
# File number 173 being processed
# File test_0_11_9.snappy.parquet not processed
# 0 11 10
# File number 173 being processed
# File test_0_11_10.snappy.parquet not processed
# 0 11 11
# File number 173 being processed
# File test_0_11_11.snappy.parquet not processed
# 0 11 12
# File number 173 being processed
# File test_0_11_12.snappy.parquet not processed
# 0 11 13
# File number 173 being processed
# File test_0_11_13.snappy.parquet not processed
# 0 11 14
# File number 173 being processed
# File test_0_11_14.snappy.parquet not processed
# 0 11 15
# File number 173 being processed
# File test_0_11_15.snappy.parquet not processed
# 0 11 16
# File number 173 being processed
# File test_0_11_16.snappy.parquet not processed
# 0 11 17
# File number 173 being processed
# File test_0_11_17.snappy.parquet not processed
# 0 11 18
# File number 173 being processed
# File test_0_11_18.snappy.parquet not processed
# 0 11 19
# File number 173 being processed
# File test_0_11_19.snappy.parquet not processed
# 0 11 20
# File number 173 being processed
# File test_0_11_20.snappy.parquet not processed
# 0 11 21
# File number 173 being processed
# File test_0_11_21.snappy.parquet not processed
# 0 11 22
# File number 173 being processed
# File test_0_11_22.snappy.parquet not processed
# 0 11 23
# File number 173 being processed
# File test_0_11_23.snappy.parquet not processed
# 0 11 24
# File number 173 being processed
# File test_0_11_24.snappy.parquet not processed
# 0 11 25
# File number 173 being processed
# File test_0_11_25.snappy.parquet not processed
# 0 11 26
# File number 173 being processed
# File test_0_11_26.snappy.parquet not processed
# 0 11 27
# File number 173 being processed
# File test_0_11_27.snappy.parquet not processed
# 0 11 28
# File number 173 being processed
# File test_0_11_28.snappy.parquet not processed
# 0 11 29
# File number 173 being processed
# File test_0_11_29.snappy.parquet not processed
# 0 12 0
# File number 173 being processed
# File test_0_12_0.snappy.parquet not processed
# 0 12 1
# File number 173 being processed
# File test_0_12_1.snappy.parquet not processed
# 0 12 2
# File number 173 being processed
# File test_0_12_2.snappy.parquet not processed
# 0 12 3
# File number 173 being processed
# File test_0_12_3.snappy.parquet not processed
# 0 12 4
# File number 173 being processed
# File test_0_12_4.snappy.parquet not processed
# 0 12 5
# File number 173 being processed
# File test_0_12_5.snappy.parquet not processed
# 0 12 6
# File number 173 being processed
# File test_0_12_6.snappy.parquet not processed
# 0 12 7
# File number 173 being processed
# File test_0_12_7.snappy.parquet not processed
# 0 12 8
# File number 173 being processed
# File test_0_12_8.snappy.parquet not processed
# 0 12 9
# File number 173 being processed
# File test_0_12_9.snappy.parquet not processed
# 0 12 10
# File number 173 being processed
# File test_0_12_10.snappy.parquet not processed
# 0 12 11
# File number 173 being processed
# File test_0_12_11.snappy.parquet not processed
# 0 12 12
# File number 173 being processed
# File test_0_12_12.snappy.parquet not processed
# 0 12 13
# File number 173 being processed
# File test_0_12_13.snappy.parquet not processed
# 0 12 14
# File number 173 being processed
# File test_0_12_14.snappy.parquet not processed
# 0 12 15
# File number 173 being processed
# File test_0_12_15.snappy.parquet not processed
# 0 12 16
# File number 173 being processed
# File test_0_12_16.snappy.parquet not processed
# 0 12 17
# File number 173 being processed
# File test_0_12_17.snappy.parquet not processed
# 0 12 18
# File number 173 being processed
# File test_0_12_18.snappy.parquet not processed
# 0 12 19
# File number 173 being processed
# File test_0_12_19.snappy.parquet not processed
# 0 12 20
# File number 173 being processed
# File test_0_12_20.snappy.parquet not processed
# 0 12 21
# File number 173 being processed
# File test_0_12_21.snappy.parquet not processed
# 0 12 22
# File number 173 being processed
# File test_0_12_22.snappy.parquet not processed
# 0 12 23
# File number 173 being processed
# File test_0_12_23.snappy.parquet not processed
# 0 12 24
# File number 173 being processed
# File test_0_12_24.snappy.parquet not processed
# 0 12 25
# File number 173 being processed
# File test_0_12_25.snappy.parquet not processed
# 0 12 26
# File number 173 being processed
# File test_0_12_26.snappy.parquet not processed
# 0 12 27
# File number 173 being processed
# File test_0_12_27.snappy.parquet not processed
# 0 12 28
# File number 173 being processed
# File test_0_12_28.snappy.parquet not processed
# 0 12 29
# File number 173 being processed
# File test_0_12_29.snappy.parquet not processed
# 0 13 0
# File number 173 being processed
# File test_0_13_0.snappy.parquet not processed
# 0 13 1
# File number 173 being processed
# File test_0_13_1.snappy.parquet not processed
# 0 13 2
# File number 173 being processed
# File test_0_13_2.snappy.parquet not processed
# 0 13 3
# File number 173 being processed
# File test_0_13_3.snappy.parquet not processed
# 0 13 4
# File number 173 being processed
# File test_0_13_4.snappy.parquet not processed
# 0 13 5
# File number 173 being processed
# File test_0_13_5.snappy.parquet not processed
# 0 13 6
# File number 173 being processed
# File test_0_13_6.snappy.parquet not processed
# 0 13 7
# File number 173 being processed
# File test_0_13_7.snappy.parquet not processed
# 0 13 8
# File number 173 being processed
# File test_0_13_8.snappy.parquet not processed
# 0 13 9
# File number 173 being processed
# File test_0_13_9.snappy.parquet not processed
# 0 13 10
# File number 173 being processed
# File test_0_13_10.snappy.parquet not processed
# 0 13 11
# File number 173 being processed
# File test_0_13_11.snappy.parquet not processed
# 0 13 12
# File number 173 being processed
# File test_0_13_12.snappy.parquet not processed
# 0 13 13
# File number 173 being processed
# File test_0_13_13.snappy.parquet not processed
# 0 13 14
# File number 173 being processed
# File test_0_13_14.snappy.parquet not processed
# 0 13 15
# File number 173 being processed
# File test_0_13_15.snappy.parquet not processed
# 0 13 16
# File number 173 being processed
# File test_0_13_16.snappy.parquet not processed
# 0 13 17
# File number 173 being processed
# File test_0_13_17.snappy.parquet not processed
# 0 13 18
# File number 173 being processed
# File test_0_13_18.snappy.parquet not processed
# 0 13 19
# File number 173 being processed
# File test_0_13_19.snappy.parquet not processed
# 0 13 20
# File number 173 being processed
# File test_0_13_20.snappy.parquet not processed
# 0 13 21
# File number 173 being processed
# File test_0_13_21.snappy.parquet not processed
# 0 13 22
# File number 173 being processed
# File test_0_13_22.snappy.parquet not processed
# 0 13 23
# File number 173 being processed
# File test_0_13_23.snappy.parquet not processed
# 0 13 24
# File number 173 being processed
# File test_0_13_24.snappy.parquet not processed
# 0 13 25
# File number 173 being processed
# File test_0_13_25.snappy.parquet not processed
# 0 13 26
# File number 173 being processed
# File test_0_13_26.snappy.parquet not processed
# 0 13 27
# File number 173 being processed
# File test_0_13_27.snappy.parquet not processed
# 0 13 28
# File number 173 being processed
# File test_0_13_28.snappy.parquet not processed
# 0 13 29
# File number 173 being processed
# File test_0_13_29.snappy.parquet not processed
# 0 14 0
# File number 173 being processed
# File test_0_14_0.snappy.parquet not processed
# 0 14 1
# File number 173 being processed
# File test_0_14_1.snappy.parquet not processed
# 0 14 2
# File number 173 being processed
# File test_0_14_2.snappy.parquet not processed
# 0 14 3
# File number 173 being processed
# File test_0_14_3.snappy.parquet not processed
# 0 14 4
# File number 173 being processed
# File test_0_14_4.snappy.parquet not processed
# 0 14 5
# File number 173 being processed
# File test_0_14_5.snappy.parquet not processed
# 0 14 6
# File number 173 being processed
# File test_0_14_6.snappy.parquet not processed
# 0 14 7
# File number 173 being processed
# File test_0_14_7.snappy.parquet not processed
# 0 14 8
# File number 173 being processed
# File test_0_14_8.snappy.parquet not processed
# 0 14 9
# File number 173 being processed
# File test_0_14_9.snappy.parquet not processed
# 0 14 10
# File number 173 being processed
# File test_0_14_10.snappy.parquet not processed
# 0 14 11
# File number 173 being processed
# File test_0_14_11.snappy.parquet not processed
# 0 14 12
# File number 173 being processed
# File test_0_14_12.snappy.parquet not processed
# 0 14 13
# File number 173 being processed
# File test_0_14_13.snappy.parquet not processed
# 0 14 14
# File number 173 being processed
# File test_0_14_14.snappy.parquet not processed
# 0 14 15
# File number 173 being processed
# File test_0_14_15.snappy.parquet not processed
# 0 14 16
# File number 173 being processed
# File test_0_14_16.snappy.parquet not processed
# 0 14 17
# File number 173 being processed
# File test_0_14_17.snappy.parquet not processed
# 0 14 18
# File number 173 being processed
# File test_0_14_18.snappy.parquet not processed
# 0 14 19
# File number 173 being processed
# File test_0_14_19.snappy.parquet not processed
# 0 14 20
# File number 173 being processed
# File test_0_14_20.snappy.parquet not processed
# 0 14 21
# File number 173 being processed
# File test_0_14_21.snappy.parquet not processed
# 0 14 22
# File number 173 being processed
# File test_0_14_22.snappy.parquet not processed
# 0 14 23
# File number 173 being processed
# File test_0_14_23.snappy.parquet not processed
# 0 14 24
# File number 173 being processed
# File test_0_14_24.snappy.parquet not processed
# 0 14 25
# File number 173 being processed
# File test_0_14_25.snappy.parquet not processed
# 0 14 26
# File number 173 being processed
# File test_0_14_26.snappy.parquet not processed
# 0 14 27
# File number 173 being processed
# File test_0_14_27.snappy.parquet not processed
# 0 14 28
# File number 173 being processed
# File test_0_14_28.snappy.parquet not processed
# 0 14 29
# File number 173 being processed
# File test_0_14_29.snappy.parquet not processed
# 0 15 0
# File number 173 being processed
# File test_0_15_0.snappy.parquet not processed
# 0 15 1
# File number 173 being processed
# File test_0_15_1.snappy.parquet not processed
# 0 15 2
# File number 173 being processed
# File test_0_15_2.snappy.parquet not processed
# 0 15 3
# File number 173 being processed
# File test_0_15_3.snappy.parquet not processed
# 0 15 4
# File number 173 being processed
# File test_0_15_4.snappy.parquet not processed
# 0 15 5
# File number 173 being processed
# File test_0_15_5.snappy.parquet not processed
# 0 15 6
# File number 173 being processed
# File test_0_15_6.snappy.parquet not processed
# 0 15 7
# File number 173 being processed
# File test_0_15_7.snappy.parquet not processed
# 0 15 8
# File number 173 being processed
# File test_0_15_8.snappy.parquet not processed
# 0 15 9
# File number 173 being processed
# File test_0_15_9.snappy.parquet not processed
# 0 15 10
# File number 173 being processed
# File test_0_15_10.snappy.parquet not processed
# 0 15 11
# File number 173 being processed
# File test_0_15_11.snappy.parquet not processed
# 0 15 12
# File number 173 being processed
# File test_0_15_12.snappy.parquet not processed
# 0 15 13
# File number 173 being processed
# File test_0_15_13.snappy.parquet not processed
# 0 15 14
# File number 173 being processed
# File test_0_15_14.snappy.parquet not processed
# 0 15 15
# File number 173 being processed
# File test_0_15_15.snappy.parquet not processed
# 0 15 16
# File number 173 being processed
# File test_0_15_16.snappy.parquet not processed
# 0 15 17
# File number 173 being processed
# File test_0_15_17.snappy.parquet not processed
# 0 15 18
# File number 173 being processed
# File test_0_15_18.snappy.parquet not processed
# 0 15 19
# File number 173 being processed
# File test_0_15_19.snappy.parquet not processed
# 0 15 20
# File number 173 being processed
# File test_0_15_20.snappy.parquet not processed
# 0 15 21
# File number 173 being processed
# File test_0_15_21.snappy.parquet not processed
# 0 15 22
# File number 173 being processed
# File test_0_15_22.snappy.parquet not processed
# 0 15 23
# File number 173 being processed
# File test_0_15_23.snappy.parquet not processed
# 0 15 24
# File number 173 being processed
# File test_0_15_24.snappy.parquet not processed
# 0 15 25
# File number 173 being processed
# File test_0_15_25.snappy.parquet not processed
# 0 15 26
# File number 173 being processed
# File test_0_15_26.snappy.parquet not processed
# 0 15 27
# File number 173 being processed
# File test_0_15_27.snappy.parquet not processed
# 0 15 28
# File number 173 being processed
# File test_0_15_28.snappy.parquet not processed
# 0 15 29
# File number 173 being processed
# File test_0_15_29.snappy.parquet not processed
# 0 16 0
# File number 173 being processed
# File test_0_16_0.snappy.parquet not processed
# 0 16 1
# File number 173 being processed
# File test_0_16_1.snappy.parquet not processed
# 0 16 2
# File number 173 being processed
# File test_0_16_2.snappy.parquet not processed
# 0 16 3
# File number 173 being processed
# File test_0_16_3.snappy.parquet not processed
# 0 16 4
# File number 173 being processed
# File test_0_16_4.snappy.parquet not processed
# 0 16 5
# File number 173 being processed
# File test_0_16_5.snappy.parquet not processed
# 0 16 6
# File number 173 being processed
# File test_0_16_6.snappy.parquet not processed
# 0 16 7
# File number 173 being processed
# File test_0_16_7.snappy.parquet not processed
# 0 16 8
# File number 173 being processed
# File test_0_16_8.snappy.parquet not processed
# 0 16 9
# File number 173 being processed
# File test_0_16_9.snappy.parquet not processed
# 0 16 10
# File number 173 being processed
# File test_0_16_10.snappy.parquet not processed
# 0 16 11
# File number 173 being processed
# File test_0_16_11.snappy.parquet not processed
# 0 16 12
# File number 173 being processed
# File test_0_16_12.snappy.parquet not processed
# 0 16 13
# File number 173 being processed
# File test_0_16_13.snappy.parquet not processed
# 0 16 14
# File number 173 being processed
# File test_0_16_14.snappy.parquet not processed
# 0 16 15
# File number 173 being processed
# File test_0_16_15.snappy.parquet not processed
# 0 16 16
# File number 173 being processed
# File test_0_16_16.snappy.parquet not processed
# 0 16 17
# File number 173 being processed
# File test_0_16_17.snappy.parquet not processed
# 0 16 18
# File number 173 being processed
# File test_0_16_18.snappy.parquet not processed
# 0 16 19
# File number 173 being processed
# File test_0_16_19.snappy.parquet not processed
# 0 16 20
# File number 173 being processed
# File test_0_16_20.snappy.parquet not processed
# 0 16 21
# File number 173 being processed
# File test_0_16_21.snappy.parquet not processed
# 0 16 22
# File number 173 being processed
# File test_0_16_22.snappy.parquet not processed
# 0 16 23
# File number 173 being processed
# File test_0_16_23.snappy.parquet not processed
# 0 16 24
# File number 173 being processed
# File test_0_16_24.snappy.parquet not processed
# 0 16 25
# File number 173 being processed
# File test_0_16_25.snappy.parquet not processed
# 0 16 26
# File number 173 being processed
# File test_0_16_26.snappy.parquet not processed
# 0 16 27
# File number 173 being processed
# File test_0_16_27.snappy.parquet not processed
# 0 16 28
# File number 173 being processed
# File test_0_16_28.snappy.parquet not processed
# 0 16 29
# File number 173 being processed
# File test_0_16_29.snappy.parquet not processed
# 0 17 0
# File number 173 being processed
# File test_0_17_0.snappy.parquet not processed
# 0 17 1
# File number 173 being processed
# File test_0_17_1.snappy.parquet not processed
# 0 17 2
# File number 173 being processed
# File test_0_17_2.snappy.parquet not processed
# 0 17 3
# File number 173 being processed
# File test_0_17_3.snappy.parquet not processed
# 0 17 4
# File number 173 being processed
# File test_0_17_4.snappy.parquet not processed
# 0 17 5
# File number 173 being processed
# File test_0_17_5.snappy.parquet not processed
# 0 17 6
# File number 173 being processed
# File test_0_17_6.snappy.parquet not processed
# 0 17 7
# File number 173 being processed
# File test_0_17_7.snappy.parquet not processed
# 0 17 8
# File number 173 being processed
# File test_0_17_8.snappy.parquet not processed
# 0 17 9
# File number 173 being processed
# File test_0_17_9.snappy.parquet not processed
# 0 17 10
# File number 173 being processed
# File test_0_17_10.snappy.parquet not processed
# 0 17 11
# File number 173 being processed
# File test_0_17_11.snappy.parquet not processed
# 0 17 12
# File number 173 being processed
# File test_0_17_12.snappy.parquet not processed
# 0 17 13
# File number 173 being processed
# File test_0_17_13.snappy.parquet not processed
# 0 17 14
# File number 173 being processed
# File test_0_17_14.snappy.parquet not processed
# 0 17 15
# File number 173 being processed
# File test_0_17_15.snappy.parquet not processed
# 0 17 16
# File number 173 being processed
# File test_0_17_16.snappy.parquet not processed
# 0 17 17
# File number 173 being processed
# File test_0_17_17.snappy.parquet not processed
# 0 17 18
# File number 173 being processed
# File test_0_17_18.snappy.parquet not processed
# 0 17 19
# File number 173 being processed
# File test_0_17_19.snappy.parquet not processed
# 0 17 20
# File number 173 being processed
# File test_0_17_20.snappy.parquet not processed
# 0 17 21
# File number 173 being processed
# File test_0_17_21.snappy.parquet not processed
# 0 17 22
# File number 173 being processed
# File test_0_17_22.snappy.parquet not processed
# 0 17 23
# File number 173 being processed
# File test_0_17_23.snappy.parquet not processed
# 0 17 24
# File number 173 being processed
# File test_0_17_24.snappy.parquet not processed
# 0 17 25
# File number 173 being processed
# File test_0_17_25.snappy.parquet not processed
# 0 17 26
# File number 173 being processed
# File test_0_17_26.snappy.parquet not processed
# 0 17 27
# File number 173 being processed
# File test_0_17_27.snappy.parquet not processed
# 0 17 28
# File number 173 being processed
# File test_0_17_28.snappy.parquet not processed
# 0 17 29
# File number 173 being processed
# File test_0_17_29.snappy.parquet not processed
# 0 18 0
# File number 173 being processed
# File test_0_18_0.snappy.parquet not processed
# 0 18 1
# File number 173 being processed
# File test_0_18_1.snappy.parquet not processed
# 0 18 2
# File number 173 being processed
# File test_0_18_2.snappy.parquet not processed
# 0 18 3
# File number 173 being processed
# File test_0_18_3.snappy.parquet not processed
# 0 18 4
# File number 173 being processed
# File test_0_18_4.snappy.parquet not processed
# 0 18 5
# File number 173 being processed
# File test_0_18_5.snappy.parquet not processed
# 0 18 6
# File number 173 being processed
# File test_0_18_6.snappy.parquet not processed
# 0 18 7
# File number 173 being processed
# File test_0_18_7.snappy.parquet not processed
# 0 18 8
# File number 173 being processed
# File test_0_18_8.snappy.parquet not processed
# 0 18 9
# File number 173 being processed
# File test_0_18_9.snappy.parquet not processed
# 0 18 10
# File number 173 being processed
# File test_0_18_10.snappy.parquet not processed
# 0 18 11
# File number 173 being processed
# File test_0_18_11.snappy.parquet not processed
# 0 18 12
# File number 173 being processed
# File test_0_18_12.snappy.parquet not processed
# 0 18 13
# File number 173 being processed
# File test_0_18_13.snappy.parquet not processed
# 0 18 14
# File number 173 being processed
# File test_0_18_14.snappy.parquet not processed
# 0 18 15
# File number 173 being processed
# File test_0_18_15.snappy.parquet not processed
# 0 18 16
# File number 173 being processed
# File test_0_18_16.snappy.parquet not processed
# 0 18 17
# File number 173 being processed
# File test_0_18_17.snappy.parquet not processed
# 0 18 18
# File number 173 being processed
# File test_0_18_18.snappy.parquet not processed
# 0 18 19
# File number 173 being processed
# File test_0_18_19.snappy.parquet not processed
# 0 18 20
# File number 173 being processed
# File test_0_18_20.snappy.parquet not processed
# 0 18 21
# File number 173 being processed
# File test_0_18_21.snappy.parquet not processed
# 0 18 22
# File number 173 being processed
# File test_0_18_22.snappy.parquet not processed
# 0 18 23
# File number 173 being processed
# File test_0_18_23.snappy.parquet not processed
# 0 18 24
# File number 173 being processed
# File test_0_18_24.snappy.parquet not processed
# 0 18 25
# File number 173 being processed
# File test_0_18_25.snappy.parquet not processed
# 0 18 26
# File number 173 being processed
# File test_0_18_26.snappy.parquet not processed
# 0 18 27
# File number 173 being processed
# File test_0_18_27.snappy.parquet not processed
# 0 18 28
# File number 173 being processed
# File test_0_18_28.snappy.parquet not processed
# 0 18 29
# File number 173 being processed
# File test_0_18_29.snappy.parquet not processed
# 0 19 0
# File number 173 being processed
# File test_0_19_0.snappy.parquet not processed
# 0 19 1
# File number 173 being processed
# File test_0_19_1.snappy.parquet not processed
# 0 19 2
# File number 173 being processed
# File test_0_19_2.snappy.parquet not processed
# 0 19 3
# File number 173 being processed
# File test_0_19_3.snappy.parquet not processed
# 0 19 4
# File number 173 being processed
# File test_0_19_4.snappy.parquet not processed
# 0 19 5
# File number 173 being processed
# File test_0_19_5.snappy.parquet not processed
# 0 19 6
# File number 173 being processed
# File test_0_19_6.snappy.parquet not processed
# 0 19 7
# File number 173 being processed
# File test_0_19_7.snappy.parquet not processed
# 0 19 8
# File number 173 being processed
# File test_0_19_8.snappy.parquet not processed
# 0 19 9
# File number 173 being processed
# File test_0_19_9.snappy.parquet not processed
# 0 19 10
# File number 173 being processed
# File test_0_19_10.snappy.parquet not processed
# 0 19 11
# File number 173 being processed
# File test_0_19_11.snappy.parquet not processed
# 0 19 12
# File number 173 being processed
# File test_0_19_12.snappy.parquet not processed
# 0 19 13
# File number 173 being processed
# File test_0_19_13.snappy.parquet not processed
# 0 19 14
# File number 173 being processed
# File test_0_19_14.snappy.parquet not processed
# 0 19 15
# File number 173 being processed
# File test_0_19_15.snappy.parquet not processed
# 0 19 16
# File number 173 being processed
# File test_0_19_16.snappy.parquet not processed
# 0 19 17
# File number 173 being processed
# File test_0_19_17.snappy.parquet not processed
# 0 19 18
# File number 173 being processed
# File test_0_19_18.snappy.parquet not processed
# 0 19 19
# File number 173 being processed
# File test_0_19_19.snappy.parquet not processed
# 0 19 20
# File number 173 being processed
# File test_0_19_20.snappy.parquet not processed
# 0 19 21
# File number 173 being processed
# File test_0_19_21.snappy.parquet not processed
# 0 19 22
# File number 173 being processed
# File test_0_19_22.snappy.parquet not processed
# 0 19 23
# File number 173 being processed
# File test_0_19_23.snappy.parquet not processed
# 0 19 24
# File number 173 being processed
# File test_0_19_24.snappy.parquet not processed
# 0 19 25
# File number 173 being processed
# File test_0_19_25.snappy.parquet not processed
# 0 19 26
# File number 173 being processed
# File test_0_19_26.snappy.parquet not processed
# 0 19 27
# File number 173 being processed
# File test_0_19_27.snappy.parquet not processed
# 0 19 28
# File number 173 being processed
# File test_0_19_28.snappy.parquet not processed
# 0 19 29
# File number 173 being processed
# File test_0_19_29.snappy.parquet not processed
# 0 20 0
# File number 173 being processed
# File test_0_20_0.snappy.parquet not processed
# 0 20 1
# File number 173 being processed
# File test_0_20_1.snappy.parquet not processed
# 0 20 2
# File number 173 being processed
# File test_0_20_2.snappy.parquet not processed
# 0 20 3
# File number 173 being processed
# File test_0_20_3.snappy.parquet not processed
# 0 20 4
# File number 173 being processed
# File test_0_20_4.snappy.parquet not processed
# 0 20 5
# File number 173 being processed
# File test_0_20_5.snappy.parquet not processed
# 0 20 6
# File number 173 being processed
# File test_0_20_6.snappy.parquet not processed
# 0 20 7
# File number 173 being processed
# File test_0_20_7.snappy.parquet not processed
# 0 20 8
# File number 173 being processed
# File test_0_20_8.snappy.parquet not processed
# 0 20 9
# File number 173 being processed
# File test_0_20_9.snappy.parquet not processed
# 0 20 10
# File number 173 being processed
# File test_0_20_10.snappy.parquet not processed
# 0 20 11
# File number 173 being processed
# File test_0_20_11.snappy.parquet not processed
# 0 20 12
# File number 173 being processed
# File test_0_20_12.snappy.parquet not processed
# 0 20 13
# File number 173 being processed
# File test_0_20_13.snappy.parquet not processed
# 0 20 14
# File number 173 being processed
# File test_0_20_14.snappy.parquet not processed
# 0 20 15
# File number 173 being processed
# File test_0_20_15.snappy.parquet not processed
# 0 20 16
# File number 173 being processed
# File test_0_20_16.snappy.parquet not processed
# 0 20 17
# File number 173 being processed
# File test_0_20_17.snappy.parquet not processed
# 0 20 18
# File number 173 being processed
# File test_0_20_18.snappy.parquet not processed
# 0 20 19
# File number 173 being processed
# File test_0_20_19.snappy.parquet not processed
# 0 20 20
# File number 173 being processed
# File test_0_20_20.snappy.parquet not processed
# 0 20 21
# File number 173 being processed
# File test_0_20_21.snappy.parquet not processed
# 0 20 22
# File number 173 being processed
# File test_0_20_22.snappy.parquet not processed
# 0 20 23
# File number 173 being processed
# File test_0_20_23.snappy.parquet not processed
# 0 20 24
# File number 173 being processed
# File test_0_20_24.snappy.parquet not processed
# 0 20 25
# File number 173 being processed
# File test_0_20_25.snappy.parquet not processed
# 0 20 26
# File number 173 being processed
# File test_0_20_26.snappy.parquet not processed
# 0 20 27
# File number 173 being processed
# File test_0_20_27.snappy.parquet not processed
# 0 20 28
# File number 173 being processed
# File test_0_20_28.snappy.parquet not processed
# 0 20 29
# File number 173 being processed
# File test_0_20_29.snappy.parquet not processed
# 0 21 0
# File number 173 being processed
# File test_0_21_0.snappy.parquet not processed
# 0 21 1
# File number 173 being processed
# File test_0_21_1.snappy.parquet not processed
# 0 21 2
# File number 173 being processed
# File test_0_21_2.snappy.parquet not processed
# 0 21 3
# File number 173 being processed
# ...
# 0 23 25
# File number 173 being processed
# File test_0_23_25.snappy.parquet not processed
# 0 23 26
# File number 173 being processed
# File test_0_23_26.snappy.parquet not processed
# 0 23 27
# File number 173 being processed
# File test_0_23_27.snappy.parquet not processed
# 0 23 28
# File number 173 being processed
# File test_0_23_28.snappy.parquet not processed
# 0 23 29
# File number 173 being processed
# File test_0_23_29.snappy.parquet not processed
# 0 24 0
# File number 173 being processed
# File test_0_24_0.snappy.parquet not processed
# 0 24 1
# File number 173 being processed
# File test_0_24_1.snappy.parquet not processed
# 0 24 2
# File number 173 being processed
# File test_0_24_2.snappy.parquet not processed
# 0 24 3
# File number 173 being processed
# File test_0_24_3.snappy.parquet not processed
# 0 24 4
# File number 173 being processed
# File test_0_24_4.snappy.parquet not processed
# 0 24 5
# File number 173 being processed
# File test_0_24_5.snappy.parquet not processed
# 0 24 6
# File number 173 being processed
# File test_0_24_6.snappy.parquet not processed
# 0 24 7
# File number 173 being processed
# File test_0_24_7.snappy.parquet not processed
# 0 24 8
# File number 173 being processed
# File test_0_24_8.snappy.parquet not processed
# 0 24 9
# File number 173 being processed
# File test_0_24_9.snappy.parquet not processed
# 0 24 10
# File number 173 being processed
# File test_0_24_10.snappy.parquet not processed
# 0 24 11
# File number 173 being processed
# File test_0_24_11.snappy.parquet not processed
# 0 24 12
# File number 173 being processed
# File test_0_24_12.snappy.parquet not processed
# 0 24 13
# File number 173 being processed
# File test_0_24_13.snappy.parquet not processed
# 0 24 14
# File number 173 being processed
# File test_0_24_14.snappy.parquet not processed
# 0 24 15
# File number 173 being processed
# File test_0_24_15.snappy.parquet not processed
# 0 24 16
# File number 173 being processed
# File test_0_24_16.snappy.parquet not processed
# 0 24 17
# File number 173 being processed
# File test_0_24_17.snappy.parquet not processed
# 0 24 18
# File number 173 being processed
# File test_0_24_18.snappy.parquet not processed
# 0 24 19
# File number 173 being processed
# File test_0_24_19.snappy.parquet not processed
# 0 24 20
# File number 173 being processed
# File test_0_24_20.snappy.parquet not processed
# 0 24 21
# File number 173 being processed
# File test_0_24_21.snappy.parquet not processed
# 0 24 22
# File number 173 being processed
# File test_0_24_22.snappy.parquet not processed
# 0 24 23
# File number 173 being processed
# File test_0_24_23.snappy.parquet not processed
# 0 24 24
# File number 173 being processed
# File test_0_24_24.snappy.parquet not processed
# 0 24 25
# File number 173 being processed
# File test_0_24_25.snappy.parquet not processed
# 0 24 26
# File number 173 being processed
# File test_0_24_26.snappy.parquet not processed
# 0 24 27
# File number 173 being processed
# File test_0_24_27.snappy.parquet not processed
# 0 24 28
# File number 173 being processed
# File test_0_24_28.snappy.parquet not processed
# 0 24 29
# File number 173 being processed
# File test_0_24_29.snappy.parquet not processed
# 0 25 0
# File number 173 being processed
# File test_0_25_0.snappy.parquet not processed
# 0 25 1
# File number 173 being processed
# File test_0_25_1.snappy.parquet not processed
# 0 25 2
# File number 173 being processed
# File test_0_25_2.snappy.parquet not processed
# 0 25 3
# File number 173 being processed
# File test_0_25_3.snappy.parquet not processed
# 0 25 4
# File number 173 being processed
# File test_0_25_4.snappy.parquet not processed
# 0 25 5
# File number 173 being processed
# File test_0_25_5.snappy.parquet not processed
# 0 25 6
# File number 173 being processed
# File test_0_25_6.snappy.parquet not processed
# 0 25 7
# File number 173 being processed
# File test_0_25_7.snappy.parquet not processed
# 0 25 8
# File number 173 being processed
# File test_0_25_8.snappy.parquet not processed
# 0 25 9
# File number 173 being processed
# File test_0_25_9.snappy.parquet not processed
# 0 25 10
# File number 173 being processed
# File test_0_25_10.snappy.parquet not processed
# 0 25 11
# File number 173 being processed
# File test_0_25_11.snappy.parquet not processed
# 0 25 12
# File number 173 being processed
# File test_0_25_12.snappy.parquet not processed
# 0 25 13
# File number 173 being processed
# File test_0_25_13.snappy.parquet not processed
# 0 25 14
# File number 173 being processed
# File test_0_25_14.snappy.parquet not processed
# 0 25 15
# File number 173 being processed
# File test_0_25_15.snappy.parquet not processed
# 0 25 16
# File number 173 being processed
# File test_0_25_16.snappy.parquet not processed
# 0 25 17
# File number 173 being processed
# File test_0_25_17.snappy.parquet not processed
# 0 25 18
# File number 173 being processed
# File test_0_25_18.snappy.parquet not processed
# 0 25 19
# File number 173 being processed
# File test_0_25_19.snappy.parquet not processed
# 0 25 20
# File number 173 being processed
# File test_0_25_20.snappy.parquet not processed
# 0 25 21
# File number 173 being processed
# File test_0_25_21.snappy.parquet not processed
# 0 25 22
# File number 173 being processed
# File test_0_25_22.snappy.parquet not processed
# 0 25 23
# File number 173 being processed
# File test_0_25_23.snappy.parquet not processed
# 0 25 24
# File number 173 being processed
# File test_0_25_24.snappy.parquet not processed
# 0 25 25
# File number 173 being processed
# File test_0_25_25.snappy.parquet not processed
# 0 25 26
# File number 173 being processed
# File test_0_25_26.snappy.parquet not processed
# 0 25 27
# File number 173 being processed
# File test_0_25_27.snappy.parquet not processed
# 0 25 28
# File number 173 being processed
# File test_0_25_28.snappy.parquet not processed
# 0 25 29
# File number 173 being processed
# File test_0_25_29.snappy.parquet not processed
# 0 26 0
# File number 173 being processed
# File test_0_26_0.snappy.parquet not processed
# 0 26 1
# File number 173 being processed
# File test_0_26_1.snappy.parquet not processed
# 0 26 2
# File number 173 being processed
# File test_0_26_2.snappy.parquet not processed
# 0 26 3
# File number 173 being processed
# File test_0_26_3.snappy.parquet not processed
# 0 26 4
# File number 173 being processed
# File test_0_26_4.snappy.parquet not processed
# 0 26 5
# File number 173 being processed
# File test_0_26_5.snappy.parquet not processed
# 0 26 6
# File number 173 being processed
# File test_0_26_6.snappy.parquet not processed
# 0 26 7
# File number 173 being processed
# File test_0_26_7.snappy.parquet not processed
# 0 26 8
# File number 173 being processed
# File test_0_26_8.snappy.parquet not processed
# 0 26 9
# File number 173 being processed
# File test_0_26_9.snappy.parquet not processed
# 0 26 10
# File number 173 being processed
# File test_0_26_10.snappy.parquet not processed
# 0 26 11
# File number 173 being processed
# File test_0_26_11.snappy.parquet not processed
# 0 26 12
# File number 173 being processed
# File test_0_26_12.snappy.parquet not processed
# 0 26 13
# File number 173 being processed
# File test_0_26_13.snappy.parquet not processed
# 0 26 14
# File number 173 being processed
# File test_0_26_14.snappy.parquet not processed
# 0 26 15
# File number 173 being processed
# File test_0_26_15.snappy.parquet not processed
# 0 26 16
# File number 173 being processed
# File test_0_26_16.snappy.parquet not processed
# 0 26 17
# File number 173 being processed
# File test_0_26_17.snappy.parquet not processed
# 0 26 18
# File number 173 being processed
# File test_0_26_18.snappy.parquet not processed
# 0 26 19
# File number 173 being processed
# File test_0_26_19.snappy.parquet not processed
# 0 26 20
# File number 173 being processed
# File test_0_26_20.snappy.parquet not processed
# 0 26 21
# File number 173 being processed
# File test_0_26_21.snappy.parquet not processed
# 0 26 22
# File number 173 being processed
# File test_0_26_22.snappy.parquet not processed
# 0 26 23
# File number 173 being processed
# File test_0_26_23.snappy.parquet not processed
# 0 26 24
# File number 173 being processed
# File test_0_26_24.snappy.parquet not processed
# 0 26 25
# File number 173 being processed
# File test_0_26_25.snappy.parquet not processed
# 0 26 26
# File number 173 being processed
# File test_0_26_26.snappy.parquet not processed
# 0 26 27
# File number 173 being processed
# File test_0_26_27.snappy.parquet not processed
# 0 26 28
# File number 173 being processed
# File test_0_26_28.snappy.parquet not processed
# 0 26 29
# File number 173 being processed
# File test_0_26_29.snappy.parquet not processed
# 0 27 0
# File number 173 being processed
# File test_0_27_0.snappy.parquet not processed
# 0 27 1
# File number 173 being processed
# File test_0_27_1.snappy.parquet not processed
# 0 27 2
# File number 173 being processed
# File test_0_27_2.snappy.parquet not processed
# 0 27 3
# File number 173 being processed
# File test_0_27_3.snappy.parquet not processed
# 0 27 4
# File number 173 being processed
# File test_0_27_4.snappy.parquet not processed
# 0 27 5
# File number 173 being processed
# File test_0_27_5.snappy.parquet not processed
# 0 27 6
# File number 173 being processed
# File test_0_27_6.snappy.parquet not processed
# 0 27 7
# File number 173 being processed
# File test_0_27_7.snappy.parquet not processed
# 0 27 8
# File number 173 being processed
# File test_0_27_8.snappy.parquet not processed
# 0 27 9
# File number 173 being processed
# File test_0_27_9.snappy.parquet not processed
# 0 27 10
# File number 173 being processed
# File test_0_27_10.snappy.parquet not processed
# 0 27 11
# File number 173 being processed
# File test_0_27_11.snappy.parquet not processed
# 0 27 12
# File number 173 being processed
# File test_0_27_12.snappy.parquet not processed
# 0 27 13
# File number 173 being processed
# File test_0_27_13.snappy.parquet not processed
# 0 27 14
# File number 173 being processed
# File test_0_27_14.snappy.parquet not processed
# 0 27 15
# File number 173 being processed
# File test_0_27_15.snappy.parquet not processed
# 0 27 16
# File number 173 being processed
# File test_0_27_16.snappy.parquet not processed
# 0 27 17
# File number 173 being processed
# File test_0_27_17.snappy.parquet not processed
# 0 27 18
# File number 173 being processed
# File test_0_27_18.snappy.parquet not processed
# 0 27 19
# File number 173 being processed
# File test_0_27_19.snappy.parquet not processed
# 0 27 20
# File number 173 being processed
# File test_0_27_20.snappy.parquet not processed
# 0 27 21
# File number 173 being processed
# File test_0_27_21.snappy.parquet not processed
# 0 27 22
# File number 173 being processed
# File test_0_27_22.snappy.parquet not processed
# 0 27 23
# File number 173 being processed
# File test_0_27_23.snappy.parquet not processed
# 0 27 24
# File number 173 being processed
# File test_0_27_24.snappy.parquet not processed
# 0 27 25
# File number 173 being processed
# File test_0_27_25.snappy.parquet not processed
# 0 27 26
# File number 173 being processed
# File test_0_27_26.snappy.parquet not processed
# 0 27 27
# File number 173 being processed
# File test_0_27_27.snappy.parquet not processed
# 0 27 28
# File number 173 being processed
# File test_0_27_28.snappy.parquet not processed
# 0 27 29
# File number 173 being processed
# File test_0_27_29.snappy.parquet not processed
# 0 28 0
# File number 173 being processed
# File test_0_28_0.snappy.parquet not processed
# 0 28 1
# File number 173 being processed
# File test_0_28_1.snappy.parquet not processed
# 0 28 2
# File number 173 being processed
# File test_0_28_2.snappy.parquet not processed
# 0 28 3
# File number 173 being processed
# File test_0_28_3.snappy.parquet not processed
# 0 28 4
# File number 173 being processed
# File test_0_28_4.snappy.parquet not processed
# 0 28 5
# File number 173 being processed
# File test_0_28_5.snappy.parquet not processed
# 0 28 6
# File number 173 being processed
# File test_0_28_6.snappy.parquet not processed
# 0 28 7
# File number 173 being processed
# File test_0_28_7.snappy.parquet not processed
# 0 28 8
# File number 173 being processed
# File test_0_28_8.snappy.parquet not processed
# 0 28 9
# File number 173 being processed
# File test_0_28_9.snappy.parquet not processed
# 0 28 10
# File number 173 being processed
# File test_0_28_10.snappy.parquet not processed
# 0 28 11
# File number 173 being processed
# File test_0_28_11.snappy.parquet not processed
# 0 28 12
# File number 173 being processed
# File test_0_28_12.snappy.parquet not processed
# 0 28 13
# File number 173 being processed
# File test_0_28_13.snappy.parquet not processed
# 0 28 14
# File number 173 being processed
# File test_0_28_14.snappy.parquet not processed
# 0 28 15
# File number 173 being processed
# File test_0_28_15.snappy.parquet not processed
# 0 28 16
# File number 173 being processed
# File test_0_28_16.snappy.parquet not processed
# 0 28 17
# File number 173 being processed
# File test_0_28_17.snappy.parquet not processed
# 0 28 18
# File number 173 being processed
# File test_0_28_18.snappy.parquet not processed
# 0 28 19
# File number 173 being processed
# File test_0_28_19.snappy.parquet not processed
# 0 28 20
# File number 173 being processed
# File test_0_28_20.snappy.parquet not processed
# 0 28 21
# File number 173 being processed
# File test_0_28_21.snappy.parquet not processed
# 0 28 22
# File number 173 being processed
# File test_0_28_22.snappy.parquet not processed
# 0 28 23
# File number 173 being processed
# File test_0_28_23.snappy.parquet not processed
# 0 28 24
# File number 173 being processed
# File test_0_28_24.snappy.parquet not processed
# 0 28 25
# File number 173 being processed
# File test_0_28_25.snappy.parquet not processed
# 0 28 26
# File number 173 being processed
# File test_0_28_26.snappy.parquet not processed
# 0 28 27
# File number 173 being processed
# File test_0_28_27.snappy.parquet not processed
# 0 28 28
# File number 173 being processed
# File test_0_28_28.snappy.parquet not processed
# 0 28 29
# File number 173 being processed
# File test_0_28_29.snappy.parquet not processed
# 0 29 0
# File number 173 being processed
# File test_0_29_0.snappy.parquet not processed
# 0 29 1
# File number 173 being processed
# File test_0_29_1.snappy.parquet not processed
# 0 29 2
# File number 173 being processed
# File test_0_29_2.snappy.parquet not processed
# 0 29 3
# File number 173 being processed
# File test_0_29_3.snappy.parquet not processed
# 0 29 4
# File number 173 being processed
# File test_0_29_4.snappy.parquet not processed
# 0 29 5
# File number 173 being processed
# File test_0_29_5.snappy.parquet not processed
# 0 29 6
# File number 173 being processed
# File test_0_29_6.snappy.parquet not processed
# 0 29 7
# File number 173 being processed
# File test_0_29_7.snappy.parquet not processed
# 0 29 8
# File number 173 being processed
# File test_0_29_8.snappy.parquet not processed
# 0 29 9
# File number 173 being processed
# File test_0_29_9.snappy.parquet not processed
# 0 29 10
# File number 173 being processed
# File test_0_29_10.snappy.parquet not processed
# 0 29 11
# File number 173 being processed
# File test_0_29_11.snappy.parquet not processed
# 0 29 12
# File number 173 being processed
# File test_0_29_12.snappy.parquet not processed
# 0 29 13
# File number 173 being processed
# File test_0_29_13.snappy.parquet not processed
# 0 29 14
# File number 173 being processed
# File test_0_29_14.snappy.parquet not processed
# 0 29 15
# File number 173 being processed
# File test_0_29_15.snappy.parquet not processed
# 0 29 16
# File number 173 being processed
# File test_0_29_16.snappy.parquet not processed
# 0 29 17
# File number 173 being processed
# File test_0_29_17.snappy.parquet not processed
# 0 29 18
# File number 173 being processed
# File test_0_29_18.snappy.parquet not processed
# 0 29 19
# File number 173 being processed
# File test_0_29_19.snappy.parquet not processed
# 0 29 20
# File number 173 being processed
# File test_0_29_20.snappy.parquet not processed
# 0 29 21
# File number 173 being processed
# File test_0_29_21.snappy.parquet not processed
# 0 29 22
# File number 173 being processed
# File test_0_29_22.snappy.parquet not processed
# 0 29 23
# File number 173 being processed
# File test_0_29_23.snappy.parquet not processed
# 0 29 24
# File number 173 being processed
# File test_0_29_24.snappy.parquet not processed
# 0 29 25
# File number 173 being processed
# File test_0_29_25.snappy.parquet not processed
# 0 29 26
# File number 173 being processed
# File test_0_29_26.snappy.parquet not processed
# 0 29 27
# File number 173 being processed
# File test_0_29_27.snappy.parquet not processed
# 0 29 28
# File number 173 being processed
# File test_0_29_28.snappy.parquet not processed
# 0 29 29
# File number 173 being processed
# File test_0_29_29.snappy.parquet not processed

# %%
len(submission)
# Out:
# 1671967

# %%
submission.drop_duplicates(subset='session_id',keep='first', inplace=True, ignore_index=False)

# %%
len(submission)
# Out:
# 1671803

# %%
submission.head()
# Out:
#    session_id                                             labels
# 0  14559324.0  558573 742581 125957 708011 78453 554660 68029...
# 1  14559325.0  78314 924983 1150993 1264351 998370 1012098 83...
# 2  14559326.0  1437425 856779 1005087 1267798 1408458 1658802...
# 3  14559327.0  1283593 1337262 805019 1338162 583260 1286363 ...
# 4  14559328.0  629014 1497441 1246247 1113863 813467 1157065 ...

# %%
# TOP CLICKS AND ORDERS IN TEST
top_clicks = ['1460571', '485256','108125','986164','1551213','754412','554660','832192','579690','33343'
              ,'1006198','688602','29735','329725','184976','1019736','496180','861401','944778','659399']

top_carts = ['485256', '33343','1460571','986164','554660','660655','1116095','152547','1022566','544144'
             ,'832192','579690','329725','1043508','558573','1006198','471073','332654','688602','29735']

top_orders = ['986164', '1460571','329725','1043508','332654','688602','29735','1495817','579690','1006198'
             ,'1022566','471073','832192','544144','836852','1825743','1236775','147526','166037','1609228']

# %%
submission_clicks=submission.copy()
submission_carts=submission.copy()
submission_orders=submission.copy()

submission_clicks['session_type']=submission_clicks['session_id'].apply(lambda x: x+'_clicks')
submission_carts['session_type']=submission_carts['session_id'].apply(lambda x: x+'_carts')
submission_orders['session_type']=submission_orders['session_id'].apply(lambda x: x+'_orders')

# %%
submission_clicks['labels']=submission_clicks['labels'].apply(lambda x: list(x.split(' ')) + top_clicks).apply(lambda x: ' '.join(x[0:20]))
submission_carts['labels']=submission_carts['labels'].apply(lambda x: list(x.split(' ')) + top_carts).apply(lambda x: ' '.join(x[0:20]))
submission_orders['labels']=submission_orders['labels'].apply(lambda x: list(x.split(' ')) + top_carts).apply(lambda x: ' '.join(x[0:20]))

# %%
submission_final=pd.concat([submission_clicks[['session_type', 'labels']],submission_carts[['session_type', 'labels']],submission_orders[['session_type', 'labels']]])

# %%
submission_final.to_csv('submission_final.csv', index=False)
